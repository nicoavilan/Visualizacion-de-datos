# %% [markdown]
# <a href="https://colab.research.google.com/github/nicoavilan/Visualizacion-de-datos/blob/main/Cambio_de_moneda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Datos históricos de cambio de moneda**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import matplotlib.animation as animation
from IPython.display import HTML

# %% [markdown]
# ## Varoles históricos del precio del Euro en Dólares

# %%
url = "https://raw.githubusercontent.com/nicoavilan/Bases-de-datos/main/EUR-USD.csv"
df = pd.read_csv(url)
df
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume
# 0     2004-07-14  1.233304  1.242005  1.232499  1.238497   1.238497     0.0
# 1     2004-07-15  1.238497  1.239203  1.233502  1.235605   1.235605     0.0
# 2     2004-07-16  1.235804  1.245997  1.233304  1.245594   1.245594     0.0
# 3     2004-07-19  1.245501  1.246401  1.240495  1.243998   1.243998     0.0
# 4     2004-07-20  1.243797  1.245594  1.230996  1.233395   1.233395     0.0
# ...          ...       ...       ...       ...       ...        ...     ...
# 4692  2022-07-08  1.016984  1.019108  1.007973  1.016984   1.016984     0.0
# 4693  2022-07-11  1.016611  1.016777  1.005429  1.016611   1.016611     0.0
# 4694  2022-07-12  1.004753  1.007384  1.000110  1.004753   1.004753     0.0
# 4695  2022-07-13  1.003311  1.011624  0.999890  1.003311   1.003311     0.0
# 4696  2022-07-14  1.003271  1.004924  0.995362  1.003271   1.003271     0.0
#
# [4697 rows x 7 columns]

# %% [markdown]
# Hay que cambiar el formato de las fechas

# %%
df.loc[0,"Date"]
# Out:
# '2004-07-14'

# %%
df["Date"] = pd.to_datetime(df["Date"], format = "%Y-%m-%d")

# %%
df.loc[0,"Date"]
# Out:
# Timestamp('2004-07-14 00:00:00')

# %%
plt.figure(figsize= (15,5))
plt.plot(df.Date,df.Open)
plt.title("Precio del Euro en dólares", fontweight="bold", size = 20)
plt.ylabel("Dólares", fontweight="bold", size = 15)
plt.show()

# %%
x = df["Date"].values
y = df["Open"].values
N = len(df)

# %%
fig=plt.figure()
ax=fig.gca()

def actualizar(i):
  ax.clear()

  ax.plot(x[:i], y[:i],'-')
  ax.set_title("Precio del Euro en dólares", fontweight="bold", size = 20)
  ax.set_ylabel("Dólares", fontweight="bold", size = 15)
  ax.plot(x[i],  y[i],'o',markersize=10,color='r')

# %%
ani=animation.FuncAnimation(fig, actualizar, range(0,N,20), interval=150)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# La animación se observa al ejecutar el código, GitHub no la genera automáticamente.

# %% [markdown]
# ## Varoles históricos del precio del Dólar en Pesos Colombianos

# %%
url = "https://raw.githubusercontent.com/nicoavilan/Bases-de-datos/main/USD-COP.csv"
df = pd.read_csv(url,sep=";")
df
# Out:
#             Fecha      TRM
# 0      27/11/1991   693.32
# 1      28/11/1991   693.99
# 2      29/11/1991   694.70
# 3      30/11/1991   694.70
# 4      01/12/1991   643.42
# ...           ...      ...
# 11188  15/07/2022  4519.65
# 11189         NaN      NaN
# 11190         NaN      NaN
# 11191         NaN      NaN
# 11192         NaN      NaN
#
# [11193 rows x 2 columns]

# %% [markdown]
# Hay que cambiar el formato de las fechas

# %%
df.loc[0,"Fecha"]
# Out:
# '27/11/1991'

# %%
df["Fecha"] = pd.to_datetime(df["Fecha"], format = "%d/%m/%Y")

# %%
df.loc[0,"Fecha"]
# Out:
# Timestamp('1991-11-27 00:00:00')

# %%
plt.figure(figsize= (15,5))
plt.plot(df.Fecha,df.TRM)
plt.title("Precio del Dólar en Pesos Colombianos", fontweight="bold", size = 20)
plt.ylabel("Pesos Colombianos", fontweight="bold", size = 15)
plt.show()

# %%
x = df["Fecha"].values
y = df["TRM"].values
N = len(df)

# %%
fig=plt.figure()
ax=fig.gca()

def actualizar(i):
  ax.clear()

  ax.plot(x[:i], y[:i],'-')
  ax.set_title("Precio del Euro en dólares", fontweight="bold", size = 20)
  ax.set_ylabel("Dólares", fontweight="bold", size = 15)
  ax.plot(x[i],  y[i],'o',markersize=10,color='r')

# %%
ani=animation.FuncAnimation(fig, actualizar, range(0,N,20), interval=150)
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# La animación se observa al ejecutar el código, GitHub no la genera automáticamente.
